# %% [markdown]
# <a href="https://colab.research.google.com/github/ian24365/DALC_Scala/blob/main/DALC_%EA%B8%B0%EC%B4%88_0_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab 실습하기

# %% [markdown]
# # 1. 마크다운으로 내 깃허브 링크 삽입하기
# (https://github.com/ian24365/DALC_Scala)

# %%
https://github.com/ian24365/DALC_Scala

# %% [markdown]
# #2. 마크다운으로 이미지 삽입하기

# %% [markdown]
# ![야수파.jpg](data:image/jpeg;base64,...)

# %%
![](data:image/jpeg;base64,...)

# %% [markdown]
# # 3.마크다운으로 수업 배운 것 정리해보기
#
#
#
# *  **텍스트 마이닝**을 왜 배워야하는지 잘 몰랐으나 다양한 활용 방법이
# 있다는 걸 최근 알게되었다.
# *   모두피움 스터디에 참여하게 되어 **데이터 마이닝**을 더욱 꼼꼼하게 공부할 수 있겠다.
#
# * "노션 정말 좋아" 라는 친구의 추천 덕분에 고민하던 블로깅 방법을 찾았다.
