# %% [markdown]
# <a href="https://colab.research.google.com/github/ian24365/DALC_Scala/blob/main/DALC_%EA%B3%B5%ED%86%B5%EA%B8%B0%EC%B4%88%EC%8A%A4%ED%84%B0%EB%94%94%EA%B3%BC%EC%A0%9C_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Matplotlib 사용법

# %%
#1. 선그림(Line Plot)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig=plt.figure()
fig=suptitle("Examplt 1: Line Plot")
ax = plt.axes()

plt.plot(x, y)
plt.plot(x, np.sin(x))

# %%
# 선색  (color = ' ')

# %%
plt.plot(x, np.sin(x-0), color='blue')
plt.plot(x, np.sin(x-0), color='g')
plt.plot(x, np.sin(x-0), color='0.75') #회색조 지정, 0과 1사이 값
plt.plot(x, np.sin(x-0), color='#FFDD44') # 16진수 코드
plt.plot(x, np.sin(x-0), color='1.0, 0.2, 0.3') # RGB튜플, 0과 1사이 값
plt.plot(x, np.sin(x-0), color='chartreuse') # 모든 HTML 색상 이름을 지원

# %%
# 선 스타일 (linestyle = ' ' )

# %%
plt.plot(x, x+1, linestyle='solid')
plt.plot(x, x+1, linestyle='dashed')
plt.plot(x, x+1, linestyle='dashdot')
plt.plot(x, x+1, linestyle='dotted')
plt.plot(x, x+1, linestyle='-')
plt.plot(x, x+1, linestyle='--')
plt.plot(x, x+1, linestyle='-.')
plt.plot(x, x+1, linestyle=':')

# %%
# 선 색과 스타일 함께

# %%
plt.plot(x, x+0, 'g') #solid green
plt.plot(x, x+1, '--c')#dashed cyan
plt.plot(x, x+2, '-k.') #dashedot black
plt.plt(x, x+3, ':r') #dotted red

# %%
#플록 조정
## 축의 범위 지정

# %%
plt.plot(x, np.cos(x))
plt.xlim(-1,11)
plt.ylim(-1.5, 1.5); # 인수의 순서만 바꿔도 상하좌우 반전가능

# %%
# x,y 축 범위 동시지정

# %%
plt.plot(x, np.cos(x*2))
plt.axis([-1, 11, -1.5, 1.5]);

# %%
#축의 스케일 변경 (지수 -> 로그)

# %%
plt.plot(x, np.exp(-x));

# %%
plt.plot(x, np.exp(-x))
plt.yscale("log");

# %%
#축의 레이블 추가

# %%
plt.plot(x, np.cos(x))
plt.title("A Cosine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
#범례(legend) 추가

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.title('Curves of Sine and Cosine')
plt.xlabel('x')
plt.legend();

# %%
# 3) 점그림 (scatter plot)

# %%
x = np.linspace(0,10,25)
plt.plot(x, x, 'o', color='r')

# %%
plt.plot(x.np.sin(x), '-og');

# %%
#선과 마커의 종류 색상 변경

# %%
x = np.linspace(0,10,30)
y = np.cos(x)
plt.plot(x, y,
         '-o',
         color='gray',
         markersize=10,
         linewidth=3,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=1.5)

plt.ylim(-1.2, 1.2);

# %% [markdown]
# 2. 다중 서브 플롯
# - subplot()
# - subplots()
# - GridSpec()

# %%
# %matplotlin inline

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

nrows,ncols=3, 4 # 3행 4열

for in in range(nrows*ncols):
    plt.subplot(nrows.ncols, i+1)
    plt.text(0.5, o.5m str(nrows,ncols,i+1)), fontsize=16, ha='center')

# %%
# 12개 그리드 서브플랏끼리 간격을 두기
plt.subplot._adjust 함수

# %%
fig = plt.figure()
fig.subplots_adjust # 기본 간격의 40% 확대
(hspace=0.4, wspace=0.4)

nrows, ncols = 3,4

for i in range(nrow*ncols):
    plt.subplot(nrow, ncols, i+1)),
    fontsize=16, ha='center')

# %%
# plt.subplots (복수형)

# %%
nrows, ncols=3, 4

fig, ax = plt.subplots(nrows, ncols, sharex='col', sharey='row')

for i in range(nrows):
    for j in range(ncols):
        ax[i,j].text(0.5, 0.5, str(i,j), fontsize=15, ha='center', color='g');

# %%
#그리드가 아닌 복잡한형태와 크기 표현
# plt.GridSpec

# %%
nrows, ncols=3,4
grid = plt.GridSpec(nro, 4, wspace=0.4, hspace=0.4)

ax1 = plt.subplot(grid[0, 0])
ax2 = plt.subplot(grid[0, 1:3])
ax3 = plt.subplot(grid[1:, :2])
ax4 = plt.subplot(grid[1:, 2])
ax5 = plt.subplot(grid[:,3])

# %%
# 위 그리드의 비율대로 서브플랏의 크기가 각각 다르다

# %%
ax1.text(0.5, 0.5, 'Fig1', fontsize=15, ha='center', color='k')
ax2.text(0.5, 0.5, 'Fig2', fontsize=15, ha='center', color='k')
ax3.text(0.5, 0.5, 'Fig3', fontsize=15, ha='center', color='k')
ax4.text(0.5, 0.5, 'Fig4', fontsize=15, ha='center', color='k')
ax5.text(0.5, 0.5, 'Fig5', fontsize=15, ha='center', color='k')

# %%
#plt.GridSpec 활용 사례

# %%
# 정규 분포 데이터 만들기

mean = [0, 0]
cov = [[1,1], [1,2]]
x,y = np.random.multivariate_normal(mean,cov,5000).T

# %%
#GridSpec으로 축 설정하기

fig = plt.figure(figure=(6,6))
grid = plt.GridSpect(4,4,hspace=0.2, wspace=0.2)
main_ax=fig.add_subplot(grid[:-1,1:])
y_hist = fig.add_subplot(grid[:-1,0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1:1:], yticklabels=[], sharex=main_ax)

# %%
# 메인 축에 점 산포하기
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# %%
#보조 축 상에 히스토그램 만들기
x_hist.hist(x, 40, histtype='stepfilled', orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40,histtype='stepfilled', orientation='horizontal', color='gray')
y_hist.invert_xaxis()
